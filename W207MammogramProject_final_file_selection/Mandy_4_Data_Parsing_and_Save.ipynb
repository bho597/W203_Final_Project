# %% [markdown]
# # Parse through data and Save to file to use for input to future models
# ## Only use images 4096 x 3328

# %% [markdown]
# ## Import Libraries

# %%
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd
from pandasql import sqldf
import time
import numpy as np
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import os
import seaborn as sns  # for nicer plots
sns.set(style="darkgrid")  # default style

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from skimage.transform import resize

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import models
from keras import layers


import pydicom
import csv

# %% [markdown]
# ## Useful functions

# %%
#Function to go from numeric label to text label
def n_to_t_label(n_label):
    if n_label == 0:
        t_label = 'noCancer'
    elif n_label == 1:
        t_label = 'withCancer'
    else:
        raise ValueError('Invalid numeric label. Expected 0 or 1, but got {}'.format(n_label))
    return t_label

# %% [markdown]
# ## Assemble dataframe of images
# ### Only include images that are 4096x3328, resize to 256x208

# %%
# Get df_joined from the file saved in notebook 4
# This data frame has the image file_names, patient_ids, outcomes (cancer or no cancer in 0/1 format and pixel information)
df_joined = pd.read_csv(r"C:\Users\mandy\Documents\MIDS\W207\W207MammogramProject\JoinedData1.csv")
print(df_joined.shape,'\n')
df_joined.head()
# Out:
# (54706, 5)
#         file_name  patient_id  cancer  n_rows_image  n_cols_image
# 0  1459541791.dcm       10006       0          5355          4915
# 1  1864590858.dcm       10006       0          5355          4915
# 2  1874946579.dcm       10006       0          5355          4915
# 3   462822612.dcm       10006       0          5355          4915
# 4  1031443799.dcm       10011       0          2776          2082

# %%
# Filter to only keep images with 4096 x 3328 pixels
df_filtered = df_joined.loc[(df_joined['n_rows_image'] == 4096) & (df_joined['n_cols_image'] == 3328)].reset_index(drop=True)
print('df_filtered shape:', df_filtered.shape, '\n')
print('df_filtered:\n',df_filtered.head())
# Out:
# df_filtered shape: (24109, 5)
#
# df_filtered:
#          file_name  patient_id  cancer  n_rows_image  n_cols_image
# 0  1007799858.dcm       10097       0          4096          3328
# 1   166011602.dcm       10097       0          4096          3328
# 2  1957744616.dcm       10097       0          4096          3328
# 3   268368896.dcm       10097       0          4096          3328
# 4   664674273.dcm       10097       0          4096          3328

# %%
# Check how many cancer vs no cancer cases we're left with after the filtering
# 600 cancer cases. No cancer is now ~97% of images vs the pre-filter 98%
# conclusion that this filter returns an ok data set, about half of the original and about the same % split outcomes
df_filtered['cancer'].value_counts()
# Out:
# 0    23509
# 1      600
# Name: cancer, dtype: int64

# %%
#Take a look at the filtered dataframe
df_filtered = df_filtered.set_index('file_name')
print(df_filtered)
print('df_filtered cancer value counts:', df_filtered['cancer'].value_counts())
print('\n98% dataset is positive for cancer')
# Out:
#                 patient_id  cancer  n_rows_image  n_cols_image
# file_name
# 1007799858.dcm       10097       0          4096          3328
# 166011602.dcm        10097       0          4096          3328
# 1957744616.dcm       10097       0          4096          3328
# 268368896.dcm        10097       0          4096          3328
# 664674273.dcm        10097       0          4096          3328
# ...                    ...     ...           ...           ...
# 244243187.dcm         9967       0          4096          3328
# 2098937312.dcm        9968       0          4096          3328
# 294168046.dcm         9968       0          4096          3328
# 568005453.dcm         9968       0          4096          3328
# 766198919.dcm         9968       0          4096          3328
#
# [24109 rows x 4 columns]
# df_filtered cancer value counts: 0    23509
# 1      600
# Name: cancer, dtype: int64
#
# 98% dataset is positive for cancer

# %%
#Take a look at column data types
df_filtered.dtypes
# Out:
# patient_id      int64
# cancer          int64
# n_rows_image    int64
# n_cols_image    int64
# dtype: object

# %%
# Set each row's index to the imageID
imageIds = df_filtered.index
print(imageIds)
# Out:
# Index(['1007799858.dcm', '166011602.dcm', '1957744616.dcm', '268368896.dcm',
#        '664674273.dcm', '929754876.dcm', '1181635673.dcm', '1241778584.dcm',
#        '1245250349.dcm', '1304802631.dcm',
#        ...
#        '255391556.dcm', '629099099.dcm', '1245697729.dcm', '1260162631.dcm',
#        '155474390.dcm', '244243187.dcm', '2098937312.dcm', '294168046.dcm',
#        '568005453.dcm', '766198919.dcm'],
#       dtype='object', name='file_name', length=24109)

# %%
#Get Data
#X is mammogram images
#y is labels

# Set the directory where DICOM files are located
dicom_directory = r"D:\W207\rsna-breast-cancer-detection\train_images"

# Initialize list of flattened training images and outcomes
images = []
labels = []

# Set a counter for the number of DICOM files found
count = 0

# Start the timer
start_time = time.time()

# Recursively search for DICOM files in all subdirectories
for root, dirs, files in os.walk(dicom_directory):
    for filename in files:
        # Check if the file is a DICOM file
        if filename.endswith(".dcm"):
            # Check if the file is in the training list
            if (imageIds == filename).any().any():
                #print(filename)
                file_path = os.path.join(root, filename)
                # Add the pixel data 
                ds = pydicom.dcmread(file_path)
                pixel_array = ds.pixel_array
                resized_pixel_array = resize(pixel_array, (256, 208), anti_aliasing=True)
                images.append(resized_pixel_array.flatten())
                # Add the label information
                labels.append(df_filtered.loc[filename,'cancer'])
            # Increment the counter
            count += 1
            if count % 100 == 0:
                print(f"Processed {count} DICOM files...")

images = np.array(images)
# Out:
# Processed 100 DICOM files...
# Processed 200 DICOM files...
# Processed 300 DICOM files...
# Processed 400 DICOM files...
# Processed 500 DICOM files...
# Processed 600 DICOM files...
# Processed 700 DICOM files...
# Processed 800 DICOM files...
# Processed 900 DICOM files...
# Processed 1000 DICOM files...
# Processed 1100 DICOM files...
# Processed 1200 DICOM files...
# Processed 1300 DICOM files...
# Processed 1400 DICOM files...
# Processed 1500 DICOM files...
# Processed 1600 DICOM files...
# Processed 1700 DICOM files...
# Processed 1800 DICOM files...
# Processed 1900 DICOM files...
# Processed 2000 DICOM files...
# Processed 2100 DICOM files...
# Processed 2200 DICOM files...
# Processed 2300 DICOM files...
# Processed 2400 DICOM files...
# Processed 2500 DICOM files...
# Processed 2600 DICOM files...
# Processed 2700 DICOM files...
# Processed 2800 DICOM files...
# Processed 2900 DICOM files...
# Processed 3000 DICOM files...
# Processed 3100 DICOM files...
# Processed 3200 DICOM files...
# Processed 3300 DICOM files...
# Processed 3400 DICOM files...
# Processed 3500 DICOM files...
# Processed 3600 DICOM files...
# Processed 3700 DICOM files...
# Processed 3800 DICOM files...
# Processed 3900 DICOM files...
# Processed 4000 DICOM files...
# Processed 4100 DICOM files...
# Processed 4200 DICOM files...
# Processed 4300 DICOM files...
# Processed 4400 DICOM files...
# Processed 4500 DICOM files...
# Processed 4600 DICOM files...
# Processed 4700 DICOM files...
# Processed 4800 DICOM files...
# Processed 4900 DICOM files...
# Processed 5000 DICOM files...
# Processed 5100 DICOM files...
# Processed 5200 DICOM files...
# Processed 5300 DICOM files...
# Processed 5400 DICOM files...
# Processed 5500 DICOM files...
# Processed 5600 DICOM files...
# Processed 5700 DICOM files...
# Processed 5800 DICOM files...
# Processed 5900 DICOM files...
# Processed 6000 DICOM files...
# Processed 6100 DICOM files...
# Processed 6200 DICOM files...
# Processed 6300 DICOM files...
# Processed 6400 DICOM files...
# Processed 6500 DICOM files...
# Processed 6600 DICOM files...
# Processed 6700 DICOM files...
# Processed 6800 DICOM files...
# Processed 6900 DICOM files...
# Processed 7000 DICOM files...
# Processed 7100 DICOM files...
# Processed 7200 DICOM files...
# Processed 7300 DICOM files...
# Processed 7400 DICOM files...
# Processed 7500 DICOM files...
# Processed 7600 DICOM files...
# Processed 7700 DICOM files...
# Processed 7800 DICOM files...
# Processed 7900 DICOM files...
# Processed 8000 DICOM files...
# Processed 8100 DICOM files...
# Processed 8200 DICOM files...
# Processed 8300 DICOM files...
# Processed 8400 DICOM files...
# Processed 8500 DICOM files...
# Processed 8600 DICOM files...
# Processed 8700 DICOM files...
# Processed 8800 DICOM files...
# Processed 8900 DICOM files...
# Processed 9000 DICOM files...
# Processed 9100 DICOM files...
# Processed 9200 DICOM files...
# Processed 9300 DICOM files...
# Processed 9400 DICOM files...
# Processed 9500 DICOM files...
# Processed 9600 DICOM files...
# Processed 9700 DICOM files...
# Processed 9800 DICOM files...
# Processed 9900 DICOM files...
# Processed 10000 DICOM files...
# Processed 10100 DICOM files...
# Processed 10200 DICOM files...
# Processed 10300 DICOM files...
# Processed 10400 DICOM files...
# Processed 10500 DICOM files...
# Processed 10600 DICOM files...
# Processed 10700 DICOM files...
# Processed 10800 DICOM files...
# Processed 10900 DICOM files...
# Processed 11000 DICOM files...
# Processed 11100 DICOM files...
# Processed 11200 DICOM files...
# Processed 11300 DICOM files...
# Processed 11400 DICOM files...
# Processed 11500 DICOM files...
# Processed 11600 DICOM files...
# Processed 11700 DICOM files...
# Processed 11800 DICOM files...
# Processed 11900 DICOM files...
# Processed 12000 DICOM files...
# Processed 12100 DICOM files...
# Processed 12200 DICOM files...
# Processed 12300 DICOM files...
# Processed 12400 DICOM files...
# Processed 12500 DICOM files...
# Processed 12600 DICOM files...
# Processed 12700 DICOM files...
# Processed 12800 DICOM files...
# Processed 12900 DICOM files...
# Processed 13000 DICOM files...
# Processed 13100 DICOM files...
# Processed 13200 DICOM files...
# Processed 13300 DICOM files...
# Processed 13400 DICOM files...
# Processed 13500 DICOM files...
# Processed 13600 DICOM files...
# Processed 13700 DICOM files...
# Processed 13800 DICOM files...
# Processed 13900 DICOM files...
# Processed 14000 DICOM files...
# Processed 14100 DICOM files...
# Processed 14200 DICOM files...
# Processed 14300 DICOM files...
# Processed 14400 DICOM files...
# Processed 14500 DICOM files...
# Processed 14600 DICOM files...
# Processed 14700 DICOM files...
# Processed 14800 DICOM files...
# Processed 14900 DICOM files...
# Processed 15000 DICOM files...
# Processed 15100 DICOM files...
# Processed 15200 DICOM files...
# Processed 15300 DICOM files...
# Processed 15400 DICOM files...
# Processed 15500 DICOM files...
# Processed 15600 DICOM files...
# Processed 15700 DICOM files...
# Processed 15800 DICOM files...
# Processed 15900 DICOM files...
# Processed 16000 DICOM files...
# Processed 16100 DICOM files...
# Processed 16200 DICOM files...
# Processed 16300 DICOM files...
# Processed 16400 DICOM files...
# Processed 16500 DICOM files...
# Processed 16600 DICOM files...
# Processed 16700 DICOM files...
# Processed 16800 DICOM files...
# Processed 16900 DICOM files...
# Processed 17000 DICOM files...
# Processed 17100 DICOM files...
# Processed 17200 DICOM files...
# Processed 17300 DICOM files...
# Processed 17400 DICOM files...
# Processed 17500 DICOM files...
# Processed 17600 DICOM files...
# Processed 17700 DICOM files...
# Processed 17800 DICOM files...
# Processed 17900 DICOM files...
# Processed 18000 DICOM files...
# Processed 18100 DICOM files...
# Processed 18200 DICOM files...
# Processed 18300 DICOM files...
# Processed 18400 DICOM files...
# Processed 18500 DICOM files...
# Processed 18600 DICOM files...
# Processed 18700 DICOM files...
# Processed 18800 DICOM files...
# Processed 18900 DICOM files...
# Processed 19000 DICOM files...
# Processed 19100 DICOM files...
# Processed 19200 DICOM files...
# Processed 19300 DICOM files...
# Processed 19400 DICOM files...
# Processed 19500 DICOM files...
# Processed 19600 DICOM files...
# Processed 19700 DICOM files...
# Processed 19800 DICOM files...
# Processed 19900 DICOM files...
# Processed 20000 DICOM files...
# Processed 20100 DICOM files...
# Processed 20200 DICOM files...
# Processed 20300 DICOM files...
# Processed 20400 DICOM files...
# Processed 20500 DICOM files...
# Processed 20600 DICOM files...
# Processed 20700 DICOM files...
# Processed 20800 DICOM files...
# Processed 20900 DICOM files...
# Processed 21000 DICOM files...
# Processed 21100 DICOM files...
# Processed 21200 DICOM files...
# Processed 21300 DICOM files...
# Processed 21400 DICOM files...
# Processed 21500 DICOM files...
# Processed 21600 DICOM files...
# Processed 21700 DICOM files...
# Processed 21800 DICOM files...
# Processed 21900 DICOM files...
# Processed 22000 DICOM files...
# Processed 22100 DICOM files...
# Processed 22200 DICOM files...
# Processed 22300 DICOM files...
# Processed 22400 DICOM files...
# Processed 22500 DICOM files...
# Processed 22600 DICOM files...
# Processed 22700 DICOM files...
# Processed 22800 DICOM files...
# Processed 22900 DICOM files...
# Processed 23000 DICOM files...
# Processed 23100 DICOM files...
# Processed 23200 DICOM files...
# Processed 23300 DICOM files...
# Processed 23400 DICOM files...
# Processed 23500 DICOM files...
# Processed 23600 DICOM files...
# Processed 23700 DICOM files...
# Processed 23800 DICOM files...
# Processed 23900 DICOM files...
# Processed 24000 DICOM files...
# Processed 24100 DICOM files...
# Processed 24200 DICOM files...
# Processed 24300 DICOM files...
# Processed 24400 DICOM files...
# Processed 24500 DICOM files...
# Processed 24600 DICOM files...
# Processed 24700 DICOM files...
# Processed 24800 DICOM files...
# Processed 24900 DICOM files...
# Processed 25000 DICOM files...
# Processed 25100 DICOM files...
# Processed 25200 DICOM files...
# Processed 25300 DICOM files...
# Processed 25400 DICOM files...
# Processed 25500 DICOM files...
# Processed 25600 DICOM files...
# Processed 25700 DICOM files...
# Processed 25800 DICOM files...
# Processed 25900 DICOM files...
# Processed 26000 DICOM files...
# Processed 26100 DICOM files...
# Processed 26200 DICOM files...
# Processed 26300 DICOM files...
# Processed 26400 DICOM files...
# Processed 26500 DICOM files...
# Processed 26600 DICOM files...
# Processed 26700 DICOM files...
# Processed 26800 DICOM files...
# Processed 26900 DICOM files...
# Processed 27000 DICOM files...
# Processed 27100 DICOM files...
# Processed 27200 DICOM files...
# Processed 27300 DICOM files...
# Processed 27400 DICOM files...
# Processed 27500 DICOM files...
# Processed 27600 DICOM files...
# Processed 27700 DICOM files...
# Processed 27800 DICOM files...
# Processed 27900 DICOM files...
# Processed 28000 DICOM files...
# Processed 28100 DICOM files...
# Processed 28200 DICOM files...
# Processed 28300 DICOM files...
# Processed 28400 DICOM files...
# Processed 28500 DICOM files...
# Processed 28600 DICOM files...
# Processed 28700 DICOM files...
# Processed 28800 DICOM files...
# Processed 28900 DICOM files...
# Processed 29000 DICOM files...
# Processed 29100 DICOM files...
# Processed 29200 DICOM files...
# Processed 29300 DICOM files...
# Processed 29400 DICOM files...
# Processed 29500 DICOM files...
# Processed 29600 DICOM files...
# Processed 29700 DICOM files...
# Processed 29800 DICOM files...
# Processed 29900 DICOM files...
# Processed 30000 DICOM files...
# Processed 30100 DICOM files...
# Processed 30200 DICOM files...
# Processed 30300 DICOM files...
# Processed 30400 DICOM files...
# Processed 30500 DICOM files...
# Processed 30600 DICOM files...
# Processed 30700 DICOM files...
# Processed 30800 DICOM files...
# Processed 30900 DICOM files...
# Processed 31000 DICOM files...
# Processed 31100 DICOM files...
# Processed 31200 DICOM files...
# Processed 31300 DICOM files...
# Processed 31400 DICOM files...
# Processed 31500 DICOM files...
# Processed 31600 DICOM files...
# Processed 31700 DICOM files...
# Processed 31800 DICOM files...
# Processed 31900 DICOM files...
# Processed 32000 DICOM files...
# Processed 32100 DICOM files...
# Processed 32200 DICOM files...
# Processed 32300 DICOM files...
# Processed 32400 DICOM files...
# Processed 32500 DICOM files...
# Processed 32600 DICOM files...
# Processed 32700 DICOM files...
# Processed 32800 DICOM files...
# Processed 32900 DICOM files...
# Processed 33000 DICOM files...
# Processed 33100 DICOM files...
# Processed 33200 DICOM files...
# Processed 33300 DICOM files...
# Processed 33400 DICOM files...
# Processed 33500 DICOM files...
# Processed 33600 DICOM files...
# Processed 33700 DICOM files...
# Processed 33800 DICOM files...
# Processed 33900 DICOM files...
# Processed 34000 DICOM files...
# Processed 34100 DICOM files...
# Processed 34200 DICOM files...
# Processed 34300 DICOM files...
# Processed 34400 DICOM files...
# Processed 34500 DICOM files...
# Processed 34600 DICOM files...
# Processed 34700 DICOM files...
# Processed 34800 DICOM files...
# Processed 34900 DICOM files...
# Processed 35000 DICOM files...
# Processed 35100 DICOM files...
# Processed 35200 DICOM files...
# Processed 35300 DICOM files...
# Processed 35400 DICOM files...
# Processed 35500 DICOM files...
# Processed 35600 DICOM files...
# Processed 35700 DICOM files...
# Processed 35800 DICOM files...
# Processed 35900 DICOM files...
# Processed 36000 DICOM files...
# Processed 36100 DICOM files...
# Processed 36200 DICOM files...
# Processed 36300 DICOM files...
# Processed 36400 DICOM files...
# Processed 36500 DICOM files...
# Processed 36600 DICOM files...
# Processed 36700 DICOM files...
# Processed 36800 DICOM files...
# Processed 36900 DICOM files...
# Processed 37000 DICOM files...
# Processed 37100 DICOM files...
# Processed 37200 DICOM files...
# Processed 37300 DICOM files...
# Processed 37400 DICOM files...
# Processed 37500 DICOM files...
# Processed 37600 DICOM files...
# Processed 37700 DICOM files...
# Processed 37800 DICOM files...
# Processed 37900 DICOM files...
# Processed 38000 DICOM files...
# Processed 38100 DICOM files...
# Processed 38200 DICOM files...
# Processed 38300 DICOM files...
# Processed 38400 DICOM files...
# Processed 38500 DICOM files...
# Processed 38600 DICOM files...
# Processed 38700 DICOM files...
# Processed 38800 DICOM files...
# Processed 38900 DICOM files...
# Processed 39000 DICOM files...
# Processed 39100 DICOM files...
# Processed 39200 DICOM files...
# Processed 39300 DICOM files...
# Processed 39400 DICOM files...
# Processed 39500 DICOM files...
# Processed 39600 DICOM files...
# Processed 39700 DICOM files...
# Processed 39800 DICOM files...
# Processed 39900 DICOM files...
# Processed 40000 DICOM files...
# Processed 40100 DICOM files...
# Processed 40200 DICOM files...
# Processed 40300 DICOM files...
# Processed 40400 DICOM files...
# Processed 40500 DICOM files...
# Processed 40600 DICOM files...
# Processed 40700 DICOM files...
# Processed 40800 DICOM files...
# Processed 40900 DICOM files...
# Processed 41000 DICOM files...
# Processed 41100 DICOM files...
# Processed 41200 DICOM files...
# Processed 41300 DICOM files...
# Processed 41400 DICOM files...
# Processed 41500 DICOM files...
# Processed 41600 DICOM files...
# Processed 41700 DICOM files...
# Processed 41800 DICOM files...
# Processed 41900 DICOM files...
# Processed 42000 DICOM files...
# Processed 42100 DICOM files...
# Processed 42200 DICOM files...
# Processed 42300 DICOM files...
# Processed 42400 DICOM files...
# Processed 42500 DICOM files...
# Processed 42600 DICOM files...
# Processed 42700 DICOM files...
# Processed 42800 DICOM files...
# Processed 42900 DICOM files...
# Processed 43000 DICOM files...
# Processed 43100 DICOM files...
# Processed 43200 DICOM files...
# Processed 43300 DICOM files...
# Processed 43400 DICOM files...
# Processed 43500 DICOM files...
# Processed 43600 DICOM files...
# Processed 43700 DICOM files...
# Processed 43800 DICOM files...
# Processed 43900 DICOM files...
# Processed 44000 DICOM files...
# Processed 44100 DICOM files...
# Processed 44200 DICOM files...
# Processed 44300 DICOM files...
# Processed 44400 DICOM files...
# Processed 44500 DICOM files...
# Processed 44600 DICOM files...
# Processed 44700 DICOM files...
# Processed 44800 DICOM files...
# Processed 44900 DICOM files...
# Processed 45000 DICOM files...
# Processed 45100 DICOM files...
# Processed 45200 DICOM files...
# Processed 45300 DICOM files...
# Processed 45400 DICOM files...
# Processed 45500 DICOM files...
# Processed 45600 DICOM files...
# Processed 45700 DICOM files...
# Processed 45800 DICOM files...
# Processed 45900 DICOM files...
# Processed 46000 DICOM files...
# Processed 46100 DICOM files...
# Processed 46200 DICOM files...
# Processed 46300 DICOM files...
# Processed 46400 DICOM files...
# Processed 46500 DICOM files...
# Processed 46600 DICOM files...
# Processed 46700 DICOM files...
# Processed 46800 DICOM files...
# Processed 46900 DICOM files...
# Processed 47000 DICOM files...
# Processed 47100 DICOM files...
# Processed 47200 DICOM files...
# Processed 47300 DICOM files...
# Processed 47400 DICOM files...
# Processed 47500 DICOM files...
# Processed 47600 DICOM files...
# Processed 47700 DICOM files...
# Processed 47800 DICOM files...
# Processed 47900 DICOM files...
# Processed 48000 DICOM files...
# Processed 48100 DICOM files...
# Processed 48200 DICOM files...
# Processed 48300 DICOM files...
# Processed 48400 DICOM files...
# Processed 48500 DICOM files...
# Processed 48600 DICOM files...
# Processed 48700 DICOM files...
# Processed 48800 DICOM files...
# Processed 48900 DICOM files...
# Processed 49000 DICOM files...
# Processed 49100 DICOM files...
# Processed 49200 DICOM files...
# Processed 49300 DICOM files...
# Processed 49400 DICOM files...
# Processed 49500 DICOM files...
# Processed 49600 DICOM files...
# Processed 49700 DICOM files...
# Processed 49800 DICOM files...
# Processed 49900 DICOM files...
# Processed 50000 DICOM files...
# Processed 50100 DICOM files...
# Processed 50200 DICOM files...
# Processed 50300 DICOM files...
# Processed 50400 DICOM files...
# Processed 50500 DICOM files...
# Processed 50600 DICOM files...
# Processed 50700 DICOM files...
# Processed 50800 DICOM files...
# Processed 50900 DICOM files...
# Processed 51000 DICOM files...
# Processed 51100 DICOM files...
# Processed 51200 DICOM files...
# Processed 51300 DICOM files...
# Processed 51400 DICOM files...
# Processed 51500 DICOM files...
# Processed 51600 DICOM files...
# Processed 51700 DICOM files...
# Processed 51800 DICOM files...
# Processed 51900 DICOM files...
# Processed 52000 DICOM files...
# Processed 52100 DICOM files...
# Processed 52200 DICOM files...
# Processed 52300 DICOM files...
# Processed 52400 DICOM files...
# Processed 52500 DICOM files...
# Processed 52600 DICOM files...
# Processed 52700 DICOM files...
# Processed 52800 DICOM files...
# Processed 52900 DICOM files...
# Processed 53000 DICOM files...
# Processed 53100 DICOM files...
# Processed 53200 DICOM files...
# Processed 53300 DICOM files...
# Processed 53400 DICOM files...
# Processed 53500 DICOM files...
# Processed 53600 DICOM files...
# Processed 53700 DICOM files...
# Processed 53800 DICOM files...
# Processed 53900 DICOM files...
# Processed 54000 DICOM files...
# Processed 54100 DICOM files...
# Processed 54200 DICOM files...
# Processed 54300 DICOM files...
# Processed 54400 DICOM files...
# Processed 54500 DICOM files...
# Processed 54600 DICOM files...
# Processed 54700 DICOM files...

# %%
import csv
#Save images and labels so don't have to walk through data again
#images
np.savez_compressed('CNN_Xs3.npz', data=images)

#labels
with open('CNN_labels3.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(labels)

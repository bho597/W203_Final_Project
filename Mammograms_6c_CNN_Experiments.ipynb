# %% [markdown]
# # CNN Model
# Some basic augmentation
#
# 600 positive cases
#
# 5000 negative cases

# %% [markdown]
# ## Import Libraries

# %%
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd
from pandasql import sqldf
import time
import numpy as np
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import os
import seaborn as sns  # for nicer plots
sns.set(style="darkgrid")  # default style

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from skimage.transform import resize
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import keras.backend as K

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import models
from keras import layers


import pydicom
import csv
import random
import pickle

# %% [markdown]
# ## Load images and labels

# %%
# Load the compressed array from disk
images_mini = np.load('CNN_Xs3.npz')['data']

# %%
# load the labels from disk
with open('CNN_labels3.csv', 'r') as file:
    reader = csv.reader(file)
    labels_mini = list(reader)[0]
    labels_mini = [int(x) for x in labels_mini]
    y_mini= np.array(labels_mini)

# %%
print('images_mini.shape:', images_mini.shape)
print('\nnumber of labels:', len(labels_mini))
print('\nnumber of positive cancer cases:', sum(labels_mini))
# Out:
# images_mini.shape: (24109, 53248)
#
# number of labels: 24109
#
# number of positive cancer cases: 600

# %% [markdown]
# ## Reduce dataset to 5k negative cases and 600 positive cases

# %%
# get indices of samples where label is 1
indices_1 = np.where(y_mini == 1)[0]

# get indices of samples where label is 0
indices_0 = np.where(y_mini == 0)[0]

# randomly choose 5000 indices from the samples where label is 0
n_samples_0 = min(len(indices_0), 5000)
indices_0 = np.random.choice(indices_0, n_samples_0, replace=False)

# combine the two sets of indices
indices = np.concatenate((indices_0, indices_1), axis=0)

# extract the selected samples from the images and labels arrays
images_selected = images_mini[indices]
labels_selected = y_mini[indices]

# this cell generated by chatgpt

# %%
# Update naming:
images_mini = images_selected
y_mini = labels_selected

# %% [markdown]
# ## Normalize pixel values to [0,1] range

# %%
print('Original max pixel value:', images_mini.max())
print('Confirm min pixel value is 0:', images_mini.min())
# Out:
# Original max pixel value: 0.062455176623178454
# Confirm min pixel value is 0: 0.0

# %%
#Normalize image pixel values
images_mini_norm = images_mini / images_mini.max()

# %%
print('New max pixel value:', images_mini_norm.max())
print('Confirm min pixel value is 0:', images_mini_norm.min())
# Out:
# New max pixel value: 1.0
# Confirm min pixel value is 0: 0.0

# %% [markdown]
# ## Make all images 3D instead of 1D

# %%
images_mini_norm.shape
# Out:
# (5600, 53248)

# %%
n_img,n_pix = images_mini_norm.shape
images_mini_norm = images_mini_norm.reshape(n_img,256,208,1)
images_mini_norm.shape
# Out:
# (5600, 256, 208, 1)

# %% [markdown]
# ## Visualize image transformations

# %%
tf.random.set_seed(1234)

fig = plt.figure(figsize=(14, 12))

# pull first image from data
image = images_mini_norm[0]

# plot original
ax = fig.add_subplot(1, 4, 1)
ax.imshow(array_to_img(image))
ax.set_title('Original', size=15);


# adjust brightness
ax = fig.add_subplot(1, 4, 2)
img_bright = tf.image.adjust_brightness(image, -.8)
ax.imshow(array_to_img(img_bright))
ax.set_title('Step 2: Brightness', size=15);


# adjust contrast
ax = fig.add_subplot(1, 4, 3)
img_contrast = tf.image.adjust_contrast(img_bright, contrast_factor=3)
ax.imshow(array_to_img(img_contrast))
ax.set_title('Step 3: Contrast', size=15);


# flip left right
ax = fig.add_subplot(1, 4, 4)
img_flip = tf.image.flip_left_right(img_contrast)
ax.imshow(array_to_img(img_flip))
ax.set_title('Step 4: Flip left right', size=15);

# %% [markdown]
# ## Split data into train, validate, test

# %%
def preprocess_data_part2(images, y, split=(0.6,0.2,0.2)):
    """ Split data into train, validation and test sets; 
    
    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    y (np.ndarray): Labels of shape (N,)   
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets
    
    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 224, 224, 1)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 224, 224, 1)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 224, 224, 1)
    y_test (np.ndarray): Test labels of shape (N_test,)
    
    """
    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator 
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images = images[shuffle]
    y = y[shuffle]
    
    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y, [splits[0], splits[0]+splits[1]])
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
    images_mini_norm,
    y_mini,
    split=(0.6,0.2,0.2)
)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"y_train positive cases {sum(y_train)}\n")

print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"y_val positive cases {sum(y_val)}\n")

print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
print(f"y_test positive cases {sum(y_test)}\n")
# Out:
# X_train shape (3360, 256, 208, 1)
# y_train shape (3360,)
# y_train positive cases 371
#
# X_val shape (1120, 256, 208, 1)
# y_val shape (1120,)
# y_val positive cases 114
#
# X_test shape (1120, 256, 208, 1)
# y_test shape (1120,)
# y_test positive cases 115

# %% [markdown]
# ## Augmentation

# %%
def preprocess_data_part3(X_train, y_train):
    
    # Augment only cancer=1 data
    X_train_w_cancer = X_train[y_train == 1, :, :, :]

    y_train_w_cancer = y_train[y_train == 1]
    
    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm1 = tf.image.adjust_brightness(X_train_w_cancer, delta=.1)
    X_train_augm2 = tf.image.adjust_brightness(X_train_w_cancer, delta=.2)
    #X_train_augm3 = tf.image.adjust_brightness(X_train_w_cancer, delta=.3)
    #X_train_augm4 = tf.image.adjust_brightness(X_train_w_cancer, delta=.4)
    
    # adjust contrast
    X_train_augm5 = tf.image.adjust_contrast(X_train_w_cancer, contrast_factor=1)
    X_train_augm6 = tf.image.adjust_contrast(X_train_w_cancer, contrast_factor=2)
    #X_train_augm7 = tf.image.adjust_contrast(X_train_w_cancer, contrast_factor=3)

    # random flip
    X_train_augm8 = tf.image.random_flip_left_right(X_train_w_cancer)
    
    # concatenate original X_train and augmented X_train data
    X_train_augm = tf.concat([X_train_augm1, X_train_augm2, X_train_augm5,
                        X_train_augm6, X_train_augm8],axis=0)
    X_train = tf.concat([X_train, X_train_augm],axis=0)
    
    # concatenate y_train (note the label is preserved)
    y_train_augm = tf.convert_to_tensor(np.ones(len(X_train_augm)))
    y_train = tf.concat([y_train, y_train_augm],axis=0)
    
    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array
    
    return X_train, y_train

# %%
X_train, y_train = preprocess_data_part3(
    X_train, y_train)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"y_train positive cases {sum(y_train)}\n")

print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"y_val positive cases {sum(y_val)}\n")

print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
print(f"y_test positive cases {sum(y_test)}\n")
# Out:
# X_train shape (5215, 256, 208, 1)
# y_train shape (5215,)
# y_train positive cases 2226.0
#
# X_val shape (1120, 256, 208, 1)
# y_val shape (1120,)
# y_val positive cases 114
#
# X_test shape (1120, 256, 208, 1)
# y_test shape (1120,)
# y_test positive cases 115

# %% [markdown]
# ## Build model

# %%
model = tf.keras.Sequential()

# add first convolution layer to the model
model.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    data_format='channels_last',
    name='conv_1',
    activation='relu'))


# add a max pooling layer with pool size (2,2) and strides of 2
# (this will reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),
    name='pool_1'))


# add second convolutional layer
model.add(tf.keras.layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    name='conv_2',
    activation='relu'))

# add second max pooling layer with pool size (2,2) and strides of 2
# (this will further reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2), name='pool_2')
)


# add a fully connected layer (need to flatten the output of the previous layers first)
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(
    units=1024,
    name='fc_1', 
    activation='relu'))

# add dropout layer
model.add(tf.keras.layers.Dropout(
    rate=0.5))

# add the last fully connected layer
# this last layer sets the activation function to "None" in order to output the logits 
# note that passing activation = "sigmoid" will return class memembership probabilities but
# in TensorFlow logits are prefered for numerical stability
# set units=1 to get a single output unit (remember it's a binary classification problem)
model.add(tf.keras.layers.Dense(
    units=1,
    name='fc_2',
    activation='sigmoid'))


# build model and print summary
tf.random.set_seed(1)
model.build(input_shape=(None, 256, 208, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 256, 208, 32)      832
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 128, 104, 32)      0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 128, 104, 64)      51264
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 64, 52, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 212992)            0
# _________________________________________________________________
# fc_1 (Dense)                 (None, 1024)              218104832
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# fc_2 (Dense)                 (None, 1)                 1025
# =================================================================
# Total params: 218,157,953
# Trainable params: 218,157,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='binary_crossentropy',
              metrics=['AUC','accuracy', 'binary_accuracy',recall_m, precision_m, f1_m])

# %%
# set random seed to get reproductible results 
# neural network algorithms are stochastic (e.g., due to random weight initialization); setting a random seed helps to get more stable results after each run
# however, best way to deal with randomness is to repeat your experiment many times (30+) and use statistics to summarize the performance of the model
tf.random.set_seed(1234)
np.random.seed(1234)
history = model.fit(X_train, y_train,
                    epochs=20, 
                    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 446s 3s/step - loss: 0.5898 - auc: 0.7484 - accuracy: 0.7457 - binary_accuracy: 0.7457 - recall_m: 0.4445 - precision_m: 0.9336 - f1_m: 0.5718 - val_loss: 0.5240 - val_auc: 0.5329 - val_accuracy: 0.8839 - val_binary_accuracy: 0.8839 - val_recall_m: 0.0190 - val_precision_m: 0.0286 - val_f1_m: 0.0229
# Epoch 2/20
# 163/163 [==============================] - 432s 3s/step - loss: 0.4270 - auc: 0.8438 - accuracy: 0.7988 - binary_accuracy: 0.7988 - recall_m: 0.5946 - precision_m: 0.9115 - f1_m: 0.7056 - val_loss: 0.3907 - val_auc: 0.5258 - val_accuracy: 0.8741 - val_binary_accuracy: 0.8741 - val_recall_m: 0.0424 - val_precision_m: 0.0952 - val_f1_m: 0.0567
# Epoch 3/20
# 163/163 [==============================] - 433s 3s/step - loss: 0.3189 - auc: 0.9266 - accuracy: 0.8614 - binary_accuracy: 0.8614 - recall_m: 0.7580 - precision_m: 0.9040 - f1_m: 0.8158 - val_loss: 0.4459 - val_auc: 0.5370 - val_accuracy: 0.8562 - val_binary_accuracy: 0.8562 - val_recall_m: 0.1155 - val_precision_m: 0.1500 - val_f1_m: 0.1248
# Epoch 4/20
# 163/163 [==============================] - 428s 3s/step - loss: 0.1803 - auc: 0.9777 - accuracy: 0.9310 - binary_accuracy: 0.9310 - recall_m: 0.8876 - precision_m: 0.9478 - f1_m: 0.9127 - val_loss: 0.4975 - val_auc: 0.5444 - val_accuracy: 0.8839 - val_binary_accuracy: 0.8839 - val_recall_m: 0.0410 - val_precision_m: 0.1238 - val_f1_m: 0.0591
# Epoch 5/20
# 163/163 [==============================] - 437s 3s/step - loss: 0.0792 - auc: 0.9957 - accuracy: 0.9722 - binary_accuracy: 0.9722 - recall_m: 0.9579 - precision_m: 0.9761 - f1_m: 0.9658 - val_loss: 0.7308 - val_auc: 0.5273 - val_accuracy: 0.8277 - val_binary_accuracy: 0.8277 - val_recall_m: 0.0969 - val_precision_m: 0.1457 - val_f1_m: 0.1080
# Epoch 6/20
# 163/163 [==============================] - 431s 3s/step - loss: 0.0344 - auc: 0.9993 - accuracy: 0.9875 - binary_accuracy: 0.9875 - recall_m: 0.9811 - precision_m: 0.9904 - f1_m: 0.9852 - val_loss: 0.6949 - val_auc: 0.5294 - val_accuracy: 0.8375 - val_binary_accuracy: 0.8375 - val_recall_m: 0.0807 - val_precision_m: 0.1058 - val_f1_m: 0.0810
# Epoch 7/20
# 163/163 [==============================] - 450s 3s/step - loss: 0.0151 - auc: 0.9997 - accuracy: 0.9965 - binary_accuracy: 0.9965 - recall_m: 0.9960 - precision_m: 0.9964 - f1_m: 0.9961 - val_loss: 1.0119 - val_auc: 0.5130 - val_accuracy: 0.8652 - val_binary_accuracy: 0.8652 - val_recall_m: 0.0652 - val_precision_m: 0.1143 - val_f1_m: 0.0741
# Epoch 8/20
# 163/163 [==============================] - 435s 3s/step - loss: 0.0100 - auc: 0.9999 - accuracy: 0.9967 - binary_accuracy: 0.9967 - recall_m: 0.9942 - precision_m: 0.9985 - f1_m: 0.9962 - val_loss: 1.0122 - val_auc: 0.5135 - val_accuracy: 0.8402 - val_binary_accuracy: 0.8402 - val_recall_m: 0.0781 - val_precision_m: 0.1153 - val_f1_m: 0.0851
# Epoch 9/20
# 163/163 [==============================] - 437s 3s/step - loss: 0.0037 - auc: 1.0000 - accuracy: 0.9992 - binary_accuracy: 0.9992 - recall_m: 0.9984 - precision_m: 1.0000 - f1_m: 0.9992 - val_loss: 1.1155 - val_auc: 0.5166 - val_accuracy: 0.8509 - val_binary_accuracy: 0.8509 - val_recall_m: 0.0781 - val_precision_m: 0.1153 - val_f1_m: 0.0855
# Epoch 10/20
# 163/163 [==============================] - 431s 3s/step - loss: 0.0042 - auc: 1.0000 - accuracy: 0.9987 - binary_accuracy: 0.9987 - recall_m: 0.9988 - precision_m: 0.9981 - f1_m: 0.9984 - val_loss: 1.2198 - val_auc: 0.5057 - val_accuracy: 0.8580 - val_binary_accuracy: 0.8580 - val_recall_m: 0.0757 - val_precision_m: 0.1024 - val_f1_m: 0.0814
# Epoch 11/20
# 163/163 [==============================] - 437s 3s/step - loss: 0.0035 - auc: 1.0000 - accuracy: 0.9994 - binary_accuracy: 0.9994 - recall_m: 0.9992 - precision_m: 0.9996 - f1_m: 0.9993 - val_loss: 1.3275 - val_auc: 0.5141 - val_accuracy: 0.8670 - val_binary_accuracy: 0.8670 - val_recall_m: 0.0576 - val_precision_m: 0.1071 - val_f1_m: 0.0701
# Epoch 12/20
# 163/163 [==============================] - 430s 3s/step - loss: 0.0013 - auc: 1.0000 - accuracy: 0.9998 - binary_accuracy: 0.9998 - recall_m: 0.9996 - precision_m: 1.0000 - f1_m: 0.9998 - val_loss: 1.3516 - val_auc: 0.4960 - val_accuracy: 0.8696 - val_binary_accuracy: 0.8696 - val_recall_m: 0.0390 - val_precision_m: 0.0548 - val_f1_m: 0.0439
# Epoch 13/20
# 163/163 [==============================] - 435s 3s/step - loss: 0.0045 - auc: 1.0000 - accuracy: 0.9987 - binary_accuracy: 0.9987 - recall_m: 0.9987 - precision_m: 0.9983 - f1_m: 0.9985 - val_loss: 1.3741 - val_auc: 0.5222 - val_accuracy: 0.8607 - val_binary_accuracy: 0.8607 - val_recall_m: 0.0390 - val_precision_m: 0.0557 - val_f1_m: 0.0425
# Epoch 14/20
# 163/163 [==============================] - 428s 3s/step - loss: 0.0058 - auc: 1.0000 - accuracy: 0.9981 - binary_accuracy: 0.9981 - recall_m: 0.9967 - precision_m: 0.9990 - f1_m: 0.9978 - val_loss: 1.3851 - val_auc: 0.4985 - val_accuracy: 0.8286 - val_binary_accuracy: 0.8286 - val_recall_m: 0.0519 - val_precision_m: 0.0676 - val_f1_m: 0.0559
# Epoch 15/20
# 163/163 [==============================] - 438s 3s/step - loss: 0.0081 - auc: 1.0000 - accuracy: 0.9971 - binary_accuracy: 0.9971 - recall_m: 0.9965 - precision_m: 0.9971 - f1_m: 0.9967 - val_loss: 1.3413 - val_auc: 0.4934 - val_accuracy: 0.8545 - val_binary_accuracy: 0.8545 - val_recall_m: 0.0367 - val_precision_m: 0.0595 - val_f1_m: 0.0401
# Epoch 16/20
# 163/163 [==============================] - 431s 3s/step - loss: 0.0110 - auc: 0.9998 - accuracy: 0.9956 - binary_accuracy: 0.9956 - recall_m: 0.9947 - precision_m: 0.9954 - f1_m: 0.9949 - val_loss: 1.3799 - val_auc: 0.4992 - val_accuracy: 0.8473 - val_binary_accuracy: 0.8473 - val_recall_m: 0.0448 - val_precision_m: 0.0505 - val_f1_m: 0.0444
# Epoch 17/20
# 163/163 [==============================] - 438s 3s/step - loss: 0.0150 - auc: 0.9995 - accuracy: 0.9948 - binary_accuracy: 0.9948 - recall_m: 0.9937 - precision_m: 0.9945 - f1_m: 0.9939 - val_loss: 1.0661 - val_auc: 0.5189 - val_accuracy: 0.8696 - val_binary_accuracy: 0.8696 - val_recall_m: 0.0471 - val_precision_m: 0.1114 - val_f1_m: 0.0577
# Epoch 18/20
# 163/163 [==============================] - 432s 3s/step - loss: 0.0064 - auc: 1.0000 - accuracy: 0.9971 - binary_accuracy: 0.9971 - recall_m: 0.9973 - precision_m: 0.9957 - f1_m: 0.9964 - val_loss: 1.3700 - val_auc: 0.5227 - val_accuracy: 0.8455 - val_binary_accuracy: 0.8455 - val_recall_m: 0.0576 - val_precision_m: 0.0671 - val_f1_m: 0.0583
# Epoch 19/20
# 163/163 [==============================] - 437s 3s/step - loss: 0.0053 - auc: 1.0000 - accuracy: 0.9983 - binary_accuracy: 0.9983 - recall_m: 0.9971 - precision_m: 0.9983 - f1_m: 0.9976 - val_loss: 1.4166 - val_auc: 0.5111 - val_accuracy: 0.8438 - val_binary_accuracy: 0.8438 - val_recall_m: 0.0900 - val_precision_m: 0.0962 - val_f1_m: 0.0891
# Epoch 20/20
# 163/163 [==============================] - 430s 3s/step - loss: 0.0042 - auc: 1.0000 - accuracy: 0.9987 - binary_accuracy: 0.9987 - recall_m: 0.9980 - precision_m: 0.9987 - f1_m: 0.9983 - val_loss: 1.1734 - val_auc: 0.5258 - val_accuracy: 0.8473 - val_binary_accuracy: 0.8473 - val_recall_m: 0.0743 - val_precision_m: 0.0762 - val_f1_m: 0.0733

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
plt.show()

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['f1_m'], '-o', label='Train f1')
ax.plot(x_arr, hist['val_f1_m'], '--<', label='Validation f1')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('f1 score', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['auc'], '-o', label='Train auc')
ax.plot(x_arr, hist['val_auc'], '--<', label='Validation auc')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('AuC', size=15)
plt.show()

# %%
# Save the model 
model.save('my_model.h5')

# save your history object
with open('history.pickle', 'wb') as file:
    pickle.dump(history.history, file)

# %%
ii
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2780/3643613577.py in <module>
# ----> 1 ii
#
# NameError: name 'ii' is not defined
